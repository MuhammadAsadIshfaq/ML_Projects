# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataa = "data.csv"

# %%
data = pd.read_csv(dataa)

# %%
data.head()
# Out:
#    crime_rate  zone  industry  near_river  pollution_level  rooms   age  \
# 0     0.00632  18.0      2.31           0            0.538  6.575  65.2
# 1     0.02731   0.0      7.07           0            0.469  6.421  78.9
# 2     0.02729   0.0      7.07           0            0.469  7.185  61.1
# 3     0.03237   0.0      2.18           0            0.458  6.998  45.8
# 4     0.06905   0.0      2.18           0            0.458  7.147  54.2
#
#    city_distance  highway_connection  tax_rate  st_ratio  black_pop  \
# 0         4.0900                   1       296      15.3     396.90
# 1         4.9671                   2       242      17.8     396.90
# 2         4.9671                   2       242      17.8     392.83
# 3         6.0622                   3       222      18.7     394.63
# 4         6.0622                   3       222      18.7     396.90
#
#    lower_stat  price
# 0        4.98   24.0
# 1        9.14   21.6
# 2        4.03   34.7
# 3        2.94   33.4
# 4        5.33   36.2

# %%
data.tail()
# Out:
#      crime_rate  zone  industry  near_river  pollution_level  rooms   age  \
# 501     0.06263   0.0     11.93           0            0.573  6.593  69.1
# 502     0.04527   0.0     11.93           0            0.573  6.120  76.7
# 503     0.06076   0.0     11.93           0            0.573  6.976  91.0
# 504     0.10959   0.0     11.93           0            0.573  6.794  89.3
# 505     0.04741   0.0     11.93           0            0.573  6.030  80.8
#
#      city_distance  highway_connection  tax_rate  st_ratio  black_pop  \
# 501         2.4786                   1       273      21.0     391.99
# 502         2.2875                   1       273      21.0     396.90
# 503         2.1675                   1       273      21.0     396.90
# 504         2.3889                   1       273      21.0     393.45
# 505         2.5050                   1       273      21.0     396.90
#
#      lower_stat  price
# 501        9.67   22.4
# 502        9.08   20.6
# 503        5.64   23.9
# 504        6.48   22.0
# 505        7.88   11.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   crime_rate          506 non-null    float64
#  1   zone                506 non-null    float64
#  2   industry            506 non-null    float64
#  3   near_river          506 non-null    int64
#  4   pollution_level     496 non-null    float64
#  5   rooms               501 non-null    float64
#  6   age                 506 non-null    float64
#  7   city_distance       506 non-null    float64
#  8   highway_connection  506 non-null    int64
#  9   tax_rate            506 non-null    int64
#  10  st_ratio            506 non-null    float64
#  11  black_pop           496 non-null    float64
#  12  lower_stat          490 non-null    float64
#  13  price               506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data.isnull().sum()
# Out:
# crime_rate             0
# zone                   0
# industry               0
# near_river             0
# pollution_level       10
# rooms                  5
# age                    0
# city_distance          0
# highway_connection     0
# tax_rate               0
# st_ratio               0
# black_pop             10
# lower_stat            16
# price                  0
# dtype: int64

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe(include="all")
# Out:
#        crime_rate        zone    industry  near_river  pollution_level  \
# count  506.000000  506.000000  506.000000  506.000000       496.000000
# mean     3.613524   11.363636   11.136779    0.069170         0.555457
# std      8.601545   23.322453    6.860353    0.253994         0.116653
# min      0.006320    0.000000    0.460000    0.000000         0.385000
# 25%      0.082045    0.000000    5.190000    0.000000         0.448000
# 50%      0.256510    0.000000    9.690000    0.000000         0.538000
# 75%      3.677083   12.500000   18.100000    0.000000         0.625750
# max     88.976200  100.000000   27.740000    1.000000         0.871000
#
#             rooms         age  city_distance  highway_connection    tax_rate  \
# count  501.000000  506.000000     506.000000          506.000000  506.000000
# mean     6.288028   68.574901       3.795043            9.549407  408.237154
# std      0.703366   28.148861       2.105710            8.707259  168.537116
# min      3.561000    2.900000       1.129600            1.000000  187.000000
# 25%      5.887000   45.025000       2.100175            4.000000  279.000000
# 50%      6.209000   77.500000       3.207450            5.000000  330.000000
# 75%      6.629000   94.075000       5.188425           24.000000  666.000000
# max      8.780000  100.000000      12.126500           24.000000  711.000000
#
#          st_ratio   black_pop  lower_stat       price
# count  506.000000  496.000000  490.000000  506.000000
# mean    18.455534  359.936371   12.579653   22.532806
# std      2.164946   86.914447    7.203494    9.197104
# min     12.600000    0.320000    1.730000    5.000000
# 25%     17.400000  376.462500    6.877500   17.025000
# 50%     19.050000  391.880000   11.110000   21.200000
# 75%     20.200000  396.285000   16.930000   25.000000
# max     22.000000  396.900000   37.970000   50.000000

# %%
# to check categorical value counts
data["near_river"].value_counts()
# Out:
# 0    471
# 1     35
# Name: near_river, dtype: int64

# %%
# columns which are categorical to check their value counts
data['zone'].value_counts()
# Out:
# 0.0      372
# 20.0      21
# 80.0      15
# 22.0      10
# 12.5      10
# 25.0      10
# 40.0       7
# 45.0       6
# 30.0       6
# 90.0       5
# 95.0       4
# 60.0       4
# 21.0       4
# 33.0       4
# 55.0       3
# 70.0       3
# 34.0       3
# 52.5       3
# 35.0       3
# 28.0       3
# 75.0       3
# 82.5       2
# 85.0       2
# 17.5       1
# 100.0      1
# 18.0       1
# Name: zone, dtype: int64

# %%
# %matplotlib inline
data.hist(bins=50,figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=[12,8])
sns.boxplot(data['crime_rate'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='crime_rate'>

# %%
plt.figure(figsize=[12,8])
sns.displot(data['crime_rate'])

# %%
plt.figure(figsize=[8, 6])
sns.scatterplot(data=data, x='crime_rate', y='price')
# Out:
# <AxesSubplot:xlabel='crime_rate', ylabel='price'>

# %%
data.columns
# Out:
# Index(['crime_rate', 'zone', 'industry', 'near_river', 'pollution_level',
#        'rooms', 'age', 'city_distance', 'highway_connection', 'tax_rate',
#        'st_ratio', 'black_pop', 'lower_stat', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=[8, 6])
sns.scatterplot(data=data, x='rooms', y='price')
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='price'>

# %%
plt.figure(figsize=[8, 6])
sns.scatterplot(data=data, x='age', y='price')
# Out:
# <AxesSubplot:xlabel='age', ylabel='price'>

# %%
plt.figure(figsize=[8, 6])
sns.boxplot(data=data, x='near_river', y='price')
# Out:
# <AxesSubplot:xlabel='near_river', ylabel='price'>

# %%
plt.figure(figsize=[8, 6])
sns.boxplot(data=data, x='highway_connection', y='price')
# Out:
# <AxesSubplot:xlabel='highway_connection', ylabel='price'>

# %%
data.columns
# Out:
# Index(['crime_rate', 'zone', 'industry', 'near_river', 'pollution_level',
#        'rooms', 'age', 'city_distance', 'highway_connection', 'tax_rate',
#        'st_ratio', 'black_pop', 'lower_stat', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=[8, 6])
sns.boxplot(data=data, x='tax_rate', y='price')
# Out:
# <AxesSubplot:xlabel='tax_rate', ylabel='price'>

# %%
plt.figure(figsize=[12,8])
sns.distplot(data['price'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
correlation = data.corr()
plt.figure(figsize=[12,8])
sns.heatmap(correlation, annot=True, cmap='crest')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, test_size=0.1, random_state=42)

# %%
len(test_data)
# Out:
# 51

# %%
X_train = train_data.drop('price', axis=1)
y_train = train_data['price']

# %%
X_train.head()
# Out:
#      crime_rate  zone  industry  near_river  pollution_level  rooms   age  \
# 281     0.03705  20.0      3.33           0           0.4429  6.968  37.2
# 22      1.23247   0.0      8.14           0           0.5380  6.142  91.7
# 101     0.11432   0.0      8.56           0           0.5200  6.781  71.3
# 268     0.54050  20.0      3.97           0           0.5750  7.470  52.6
# 485     3.67367   0.0     18.10           0           0.5830  6.312  51.9
#
#      city_distance  highway_connection  tax_rate  st_ratio  black_pop  \
# 281         5.2447                   5       216      14.9     392.23
# 22          3.9769                   4       307      21.0     396.90
# 101         2.8561                   5       384      20.9     395.58
# 268         2.8720                   5       264      13.0     390.30
# 485         3.9917                  24       666      20.2     388.62
#
#      lower_stat
# 281        4.59
# 22          NaN
# 101        7.67
# 268        3.16
# 485       10.58

# %%
y_train.head()
# Out:
# 281    35.4
# 22     15.2
# 101    26.5
# 268    43.5
# 485    21.2
# Name: price, dtype: float64

# %%
X_test = test_data.drop('price', axis=1)
y_test = test_data['price']

# %%
X_test.head()
# Out:
#      crime_rate  zone  industry  near_river  pollution_level  rooms   age  \
# 173     0.09178   0.0      4.05           0            0.510  6.416  84.1
# 274     0.05644  40.0      6.41           1            0.447  6.758  32.9
# 491     0.10574   0.0     27.74           0            0.609  5.983  98.8
# 72      0.09164   0.0     10.81           0            0.413  6.065   7.8
# 452     5.09017   0.0     18.10           0            0.713  6.297  91.8
#
#      city_distance  highway_connection  tax_rate  st_ratio  black_pop  \
# 173         2.6463                   5       296      16.6     395.50
# 274         4.0776                   4       254      17.6     396.90
# 491         1.8681                   4       711      20.1     390.11
# 72          5.2873                   4       305      19.2     390.91
# 452         2.3682                  24       666      20.2     385.09
#
#      lower_stat
# 173        9.04
# 274        3.53
# 491       18.07
# 72         5.52
# 452       17.27

# %%
plt.figure(figsize=[12,8])
sns.distplot(data['crime_rate'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='crime_rate', ylabel='Density'>

# %%
plt.figure(figsize=[12,8])
sns.distplot(data['near_river'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='near_river', ylabel='Density'>

# %%
plt.figure(figsize=[12,8])
sns.distplot(data['industry'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='industry', ylabel='Density'>

# %%
plt.figure(figsize=[12,8])
sns.distplot(data['city_distance'])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='city_distance', ylabel='Density'>

# %%
plt.figure(figsize=[12,8])
sns.distplot(data["highway_connection"])
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='highway_connection', ylabel='Density'>

# %%
cat_feats = X_train[["near_river"]]

# %%
cat_feats.head()
# Out:
#      near_river
# 281           0
# 22            0
# 101           0
# 268           0
# 485           0

# %%
# Build a categorical feature OneHotEncoder pipeline to produce cat_feats_preprocessed
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

cat_feats_pipe = Pipeline([
    ('encoder', OneHotEncoder())
])
cat_feats_preprocessed = cat_feats_pipe.fit_transform(cat_feats)
cat_feats_preprocessed
# Out:
# <455x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 455 stored elements in Compressed Sparse Row format>

# %%
num_feats = X_train[['crime_rate', 'zone', 'industry', 'pollution_level',
       'rooms', 'age', 'city_distance', 'highway_connection', 'tax_rate',
       'st_ratio', 'black_pop', 'lower_stat']]
num_feats.head()
# Out:
#      crime_rate  zone  industry  pollution_level  rooms   age  city_distance  \
# 281     0.03705  20.0      3.33           0.4429  6.968  37.2         5.2447
# 22      1.23247   0.0      8.14           0.5380  6.142  91.7         3.9769
# 101     0.11432   0.0      8.56           0.5200  6.781  71.3         2.8561
# 268     0.54050  20.0      3.97           0.5750  7.470  52.6         2.8720
# 485     3.67367   0.0     18.10           0.5830  6.312  51.9         3.9917
#
#      highway_connection  tax_rate  st_ratio  black_pop  lower_stat
# 281                   5       216      14.9     392.23        4.59
# 22                    4       307      21.0     396.90         NaN
# 101                   5       384      20.9     395.58        7.67
# 268                   5       264      13.0     390.30        3.16
# 485                  24       666      20.2     388.62       10.58

# %%
# Build a numerical Standardization pipeline to produce num_feats_preprocessed
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 

num_feats_pipe = Pipeline([
    ('scalar', StandardScaler())
])
num_feats_preprocessed = num_feats_pipe.fit_transform(num_feats)
num_feats_preprocessed
# Out:
# array([[-0.41694218,  0.34451337, -1.11796605, ..., -1.60174615,
#          0.38197393, -1.08772155],
#        [-0.2800016 , -0.49972297, -0.42106823, ...,  1.1755678 ,
#          0.43426678,         nan],
#        [-0.40809056, -0.49972297, -0.36021645, ...,  1.13003807,
#          0.41948594, -0.66254697],
#        ...,
#        [-0.41946696,  2.87722238, -1.30921451, ..., -0.64562168,
#          0.36752901, -0.89446038],
#        [ 0.85728607, -0.49972297,  1.02198836, ...,  0.81132991,
#         -2.78000805,  1.49093462],
#        [-0.39498096, -0.49972297, -0.36021645, ...,  1.13003807,
#         -3.21727484, -0.25393765]])

# %%
# Build Final pipeline by combing above two pipelines. Use ColumnTransformer

from sklearn.compose import ColumnTransformer

num_list = list(num_feats)
cat_list = list(cat_feats)

final_pipe = ColumnTransformer([
    ('num', num_feats_pipe, num_list),
    ('cat', cat_feats_pipe, cat_list)
])

X_train_preprocessed = final_pipe.fit_transform(X_train)
X_train_preprocessed
# Out:
# array([[-0.41694218,  0.34451337, -1.11796605, ..., -1.08772155,
#          1.        ,  0.        ],
#        [-0.2800016 , -0.49972297, -0.42106823, ...,         nan,
#          1.        ,  0.        ],
#        [-0.40809056, -0.49972297, -0.36021645, ..., -0.66254697,
#          1.        ,  0.        ],
#        ...,
#        [-0.41946696,  2.87722238, -1.30921451, ..., -0.89446038,
#          1.        ,  0.        ],
#        [ 0.85728607, -0.49972297,  1.02198836, ...,  1.49093462,
#          1.        ,  0.        ],
#        [-0.39498096, -0.49972297, -0.36021645, ..., -0.25393765,
#          1.        ,  0.        ]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
print(data.isnull().sum())
# Out:
# crime_rate             0
# zone                   0
# industry               0
# near_river             0
# pollution_level       10
# rooms                  5
# age                    0
# city_distance          0
# highway_connection     0
# tax_rate               0
# st_ratio               0
# black_pop             10
# lower_stat            16
# price                  0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
X_train_preprocessed = imputer.fit_transform(X_train)

# %%
data.dtype
# Out:
# dtype('float64')

# %%
# Fit it with X_train_preprocessed and y_train
reg_model = model.fit(X_train_preprocessed, y_train)
reg_model
# Out:
# LinearRegression()

# %%
a1 = reg_model.coef_
a2 = reg_model.coef_
a1
# Out:
# array([-1.26950593e-01,  3.88792869e-02,  2.42687921e-02,  2.61052524e+00,
#        -1.66060710e+01,  3.89963998e+00, -6.46975063e-03, -1.49251427e+00,
#         3.17505805e-01, -1.16468129e-02, -9.57118189e-01,  1.31298570e-02,
#        -5.41836815e-01])

# %%
y_train_pred = reg_model.predict(X_train_preprocessed)

# %%
# Create a distplot of y_train and y_train_pred i.e. actual charges and predicted charges 
plt.figure(figsize = [12, 8])
sns.distplot(y_train)
sns.distplot(y_train_pred)
# Out:
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hp 840 G2\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
# Determine RMSE for predictions of train data
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_train, y_train_pred)
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 4.744970241389482

# %%
# Obtain X_test_preprocessed from X_test by applying the pipeline
X_test_preprocessed = final_pipe.fit_transform(X_test)
X_test_preprocessed
# Out:
# array([[-4.08596749e-01, -3.76101391e-01, -1.24360468e+00,
#         -3.92969678e-01,  4.21399395e-01,  4.58485897e-01,
#         -6.17898071e-01, -5.22274812e-01, -6.59804106e-01,
#         -1.21528683e+00,  3.34037639e-01, -6.74757537e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.13478745e-01,  1.73461893e+00, -8.71848328e-01,
#         -9.86274304e-01,  9.68685191e-01, -1.39706025e+00,
#          4.00280059e-01, -6.34663062e-01, -9.00693895e-01,
#         -6.60411016e-01,  3.58214483e-01, -1.49938470e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [-4.06668264e-01, -3.76101391e-01,  2.48813597e+00,
#          5.39366163e-01, -2.71509230e-01,  9.91230591e-01,
#         -1.17148308e+00, -6.34663062e-01,  1.72041643e+00,
#          7.26778515e-01,  2.40956789e-01,  6.76673186e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.08616089e-01, -3.76101391e-01, -1.78743270e-01,
#         -1.30647045e+00, -1.40288659e-01, -2.30671275e+00,
#          1.26081949e+00, -6.34663062e-01, -6.08184865e-01,
#          2.27390284e-01,  2.54772129e-01, -1.20156110e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 2.81898927e-01, -3.76101391e-01,  9.69605793e-01,
#          1.51878967e+00,  2.30969542e-01,  7.37542641e-01,
#         -8.15728951e-01,  1.61310195e+00,  1.46232023e+00,
#          7.82266096e-01,  1.54265534e-01,  5.56945104e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4
+00,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.14462327e-01,  1.36524288e+00, -1.53817433e+00,
#         -7.50835960e-01,  1.11430802e+00, -4.16417755e-02,
#         -2.36321359e-01, -2.97498311e-01, -1.08422897e+00,
#         -2.16510366e-01,  3.58214483e-01, -9.00744291e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.18500265e-01,  4.63685938e+00, -1.45941239e+00,
#         -1.27727610e+00,  3.01060529e+00, -1.43330139e+00,
#          1.14038523e+00, -6.34663062e-01, -1.07275803e+00,
#         -2.26955087e+00,  2.48555226e-01, -1.59666377e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.02551585e-01,  2.83498710e-01, -9.25406446e-01,
#         -1.34414059e+00, -8.94006817e-01, -1.25571982e+00,
#          2.12207028e+00, -6.34663062e-01, -3.78766018e-01,
#          6.09275402e-02,  3.58214483e-01, -6.86341229e-02,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.14804923e-01, -3.76101391e-01, -1.34441996e+00,
#         -5.90737886e-01,  4.22999645e-01, -1.93854545e-01,
#         -3.00628843e-01, -8.59439564e-01, -8.08926357e-01,
#         -5.49435853e-01,  2.76703980e-01, -7.09179360e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [ 5.40501015e-01, -3.76101391e-01,  9.69605793e-01,
#          1.39636173e+00, -7.03576964e-01,  9.25996547e-01,
#         -1.12993930e+00,  1.61310195e+00,  1.46232023e+00,
#          7.82266096e-01,  3.15559622e-01,  5.32999488e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-2.62172803e-01, -3.76101391e-01, -5.99332021e-01,
#         -1.29278733e-01, -7.22779974e-01,  8.53514276e-01,
#          1.93699378e-01, -6.34663062e-01, -5.96713923e-01,
#          1.22616675e+00, -3.00259134e-01,  7.18578015e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.09083015e-01, -3.76101391e-01, -1.78743270e-01,
#         -1.30647045e+00,  4.22999645e-01, -2.35020212e+00,
#          1.26081949e+00, -6.34663062e-01, -6.08184865e-01,
#          2.27390284e-01,  1.30779457e-01, -1.02196897e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 1.79482011e-01, -3.76101391e-01,  9.69605793e-01,
#          2.66257684e-01,  2.29369291e-02,  4.54861783e-01,
#         -3.42528300e-01,  1.61310195e+00,  1.46232023e+00,
#          7.82266096e-01,  3.58214483e-01,  4.10278204e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.20402503e-01,  5.73722755e-01, -1.51769622e+00,
#         -1.29278733e-01,  6.75839282e-01, -2.26471567e-01,
#          4.09100997e-01, -9.71827814e-01, -6.59804106e-01,
#         -1.93662538e+00,  3.58214483e-01, -1.28237755e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [-4.05047840e-01,  2.83498710e-01, -6.41863468e-01,
#         -2.61124205e-01, -2.29902708e-01,  4.14996534e-01,
#          1.92907669e+00, -5.22274812e-01, -5.73772038e-01,
#         -1.99211297e+00,  3.58214483e-01, -4.16953045e-02,
#          1.00000000e+00,  0.00000000e+00]])

# %%
# Obtain y_test_pred i.e. predicted values for test data
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
X_test_preprocessed = imputer.fit_transform(X_test)

# %%
y_test_pred = reg_model.predict(X_test_preprocessed)

# %%
# Determine the accuracy of the training data predictions
reg_model.score(X_train_preprocessed, y_train)
# Out:
# 0.7400878454140036

# %%
# Determine the accuracy of the test data predictions
reg_model.score(X_test_preprocessed, y_test)
# Out:
# 0.7791913951593056
